# %%
from regularizecv import *

model = main()

print("Name: Dorien Penebacker")
print("Github Username: dpenebac")
print("Purdue Username: 0031694522")
print("Instructor: iforget")
print("\nProblem1 Writeup")
print("\n\033[4mEstimated Functions:\033[0m\n")

def upper(x, m): #function for superscript
    x = m - x
    x = x + 1
    if x == 1:
        return("")
    elif x == 2:
        return("\u00B2")
    elif x == 3:
        return("\u00B3")
    else:
        return(chr(ord("\u2070") + x))
i = 8
subscript = "\u2081"
print("y", sep = '', end = ' = ')
y = '' #reset value for each y
for j in range(0, len(model.coef_[0])):
    y += ("{:.3f}".format(model.coef_[0][j])).rjust(6) + "x" + upper(j, i)
    y += " + "
y += (("{:.3f}".format(model.intercept_[0])).rjust(6))
print(y)
# Out:
# Best lambda tested is 14.45439770745928, which yields an MSE of 1811976.910951057
# y = 5112.572x⁹ + -201.037x⁸ + -207.151x⁷ + -1331.534x⁶ + 217.847x⁵ + -68.753x⁴ + 500.945x³ + 74.336x² + -458.989x + 3928.077
